# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# %%
# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_ride = pyber_data_df.groupby(["type"]).count()["ride_id"]

# %%
total_ride
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers = city_data_df.groupby(["type"]).sum()["driver_count"]

# %%
total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fare_amount = pyber_data_df.groupby(["type"]).sum()["fare"]

# %%
total_fare_amount
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 

average_ride_fare = pyber_data_df.groupby(["type"]).mean()["fare"]

average_ride_fare = total_fare_amount/total_ride

# %%
average_ride_fare
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type.
average_driver_fare = total_fare_amount / total_drivers

# %%
average_driver_fare
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df=pd.DataFrame({
        "Total Rides": total_ride,
        "Total Drivers": total_drivers,
        "Total Fares": total_fare_amount,
        "Average Fare per Ride": average_ride_fare,
        "Average Fare per Driver": average_driver_fare})

# %%
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:.2f}".format)

# %%
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head()
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

sum_type_dates = pyber_data_df.groupby(["date", "type"]).sum()[["fare"]]

# %%
sum_type_dates
# Out:
#                           fare
# date           type
# 1/1/2019 0:08  Urban     37.91
# 1/1/2019 0:46  Suburban  47.74
# 1/1/2019 12:32 Suburban  25.56
# 1/1/2019 14:40 Urban      5.42
# 1/1/2019 14:42 Urban     12.31
# ...                        ...
# 5/8/2019 1:54  Urban     32.69
# 5/8/2019 2:31  Urban     41.33
# 5/8/2019 4:20  Urban     21.99
# 5/8/2019 4:39  Urban     18.45
# 5/8/2019 7:29  Urban     18.55
#
# [2364 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
sum_type_dates = sum_type_dates.reset_index()
sum_type_dates
# Out:
#                 date      type   fare
# 0      1/1/2019 0:08     Urban  37.91
# 1      1/1/2019 0:46  Suburban  47.74
# 2     1/1/2019 12:32  Suburban  25.56
# 3     1/1/2019 14:40     Urban   5.42
# 4     1/1/2019 14:42     Urban  12.31
# ...              ...       ...    ...
# 2359   5/8/2019 1:54     Urban  32.69
# 2360   5/8/2019 2:31     Urban  41.33
# 2361   5/8/2019 4:20     Urban  21.99
# 2362   5/8/2019 4:39     Urban  18.45
# 2363   5/8/2019 7:29     Urban  18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pyber_date_pivot = sum_type_dates.pivot(index="date", columns="type") ["fare"]
pyber_date_pivot
# Out:
# type            Rural  Suburban  Urban
# date
# 1/1/2019 0:08     NaN       NaN  37.91
# 1/1/2019 0:46     NaN     47.74    NaN
# 1/1/2019 12:32    NaN     25.56    NaN
# 1/1/2019 14:40    NaN       NaN   5.42
# 1/1/2019 14:42    NaN       NaN  12.31
# ...               ...       ...    ...
# 5/8/2019 1:54     NaN       NaN  32.69
# 5/8/2019 2:31     NaN       NaN  41.33
# 5/8/2019 4:20     NaN       NaN  21.99
# 5/8/2019 4:39     NaN       NaN  18.45
# 5/8/2019 7:29     NaN       NaN  18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
pyber_date_pivot['2019-01-01': '2019-04-29']
# Out:
# C:\Users\Dell 17\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 12:32:00    NaN     25.56    NaN
# 2019-01-01 14:40:00    NaN       NaN   5.42
# 2019-01-01 14:42:00    NaN       NaN  12.31
# ...                    ...       ...    ...
# 2019-04-09 20:55:00    NaN       NaN  24.99
# 2019-04-09 21:41:00    NaN       NaN  15.96
# 2019-04-09 08:10:00    NaN       NaN  39.36
# 2019-04-09 08:47:00    NaN       NaN   4.95
# 2019-04-09 09:17:00    NaN       NaN  20.31
#
# [2204 rows x 3 columns]

# %%
pyber_date_pivot_new = pyber_date_pivot.loc['2019-01-01':'2019-04-29']
pyber_date_pivot_new.head(20)
# Out:
# C:\Users\Dell 17\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   """Entry point for launching an IPython kernel.
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 12:32:00    NaN     25.56    NaN
# 2019-01-01 14:40:00    NaN       NaN   5.42
# 2019-01-01 14:42:00    NaN       NaN  12.31
# 2019-01-01 14:52:00    NaN     31.15    NaN
# 2019-01-01 17:22:00    NaN       NaN  42.11
# 2019-01-01 21:04:00    NaN       NaN  11.71
# 2019-01-01 02:07:00    NaN     24.07    NaN
# 2019-01-01 03:46:00    NaN       NaN   7.57
# 2019-01-01 05:23:00    NaN       NaN  10.75
# 2019-01-01 09:45:00  43.69       NaN    NaN
# 2019-01-10 00:17:00    NaN     47.52    NaN
# 2019-01-10 11:08:00    NaN     37.96    NaN
# ...

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)

pyber_date_pivot.index = pd.to_datetime(pyber_date_pivot.index)
pyber_date_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2361 entries, 2019-01-01 00:08:00 to 2019-05-08 07:29:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     125 non-null    float64
#  1   Suburban  622 non-null    float64
#  2   Urban     1617 non-null   float64
# dtypes: float64(3)
# memory usage: 138.3 KB

# %%
# 7. Check that the datatype for the index is datetime using df.info()

pyber_date_pivot_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2204 entries, 2019-01-01 00:08:00 to 2019-04-09 09:17:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     116 non-null    float64
#  1   Suburban  576 non-null    float64
#  2   Urban     1515 non-null   float64
# dtypes: float64(3)
# memory usage: 68.9 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
pyber_date_pivot_new = pyber_date_pivot_new.resample("W").sum()

pyber_date_pivot_new
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29
# 2019-05-05   67.60    167.92   342.63

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

#Plot the pivot table
pyber_date_pivot_table.plot(figsize=(20,10))


# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($USD)")
#plt.line(label = "type")

# Set the y limit between 0 and 2500.
plt.ylim(0, 2500)

# Create a title.
plt.title("Total Fare by City Type")

# Add the legend.
plt.legend()

#Save the figure
plt.savefig("Analysis/PyBer_fare_summary.png")
